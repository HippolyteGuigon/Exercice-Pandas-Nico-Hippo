# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import warnings 

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("vaccination-data.csv")
df_na = df.copy()

# %% [markdown]
# ## 1. Fill the missing values for each country, with the average of its continent (and attribute the value unkown to Nan continents)

# %% [markdown]
# ## 2. Create a new column How_variating, per country, printing 1 if the new_cases variation is more than 10% than yesterday

# %% [markdown]
# ## 3. Plot, for North America, month after month, the total number of deaths, new cases and vaccinated people

# %% [markdown]
# ## 4. How many people in France or in Croatia were dead after the 1st of July 2021 ?

# %% [markdown]
# ## 5. Merge with the full_grouped dataset according to both date and country to have the number of remissions

# %% [markdown]
# ## 6. Create a new column, average_continent death, showing for a very country at a given date, the percentage of death he represents for his continent

# %% [markdown]
# ## 7. Build a pipeline which predicts, for a given date, the number of total vaccinations (you must use all columns provided)

# %% [markdown]
# ## 8. Plot the feature importance of your model

# %% [markdown]
# ## 9. It seems that there are two many features in your model, run a PCA to reduce to 3 dimensions

# %% [markdown]
# ## 10. Include the PCA in your pipeline and check the change in accuracy
